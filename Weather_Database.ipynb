# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from config import weather_api_key
import requests
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Build the URL
weather_url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid='+weather_api_key

# %% [markdown]
# # Example how to see the information for a specific city to create the API request loop

# %%
#city_url = weather_url + "&q=" + "Boston"

# %%
#city_weather = requests.get(city_url)

# %%
# # Get the JSON text of the 'Get' request.
# city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 75.15,
#   'feels_like': 74.52,
#   'temp_min': 71.6,
#   'temp_max': 77,
#   'pressure': 1012,
#   'humidity': 46},
#  'visibility': 10000,
#  'wind': {'speed': 5.75, 'deg': 0},
#  'clouds': {'all': 75},
#  'dt': 1618080301,
#  'sys': {'type': 1,
#   'id': 4967,
#   'country': 'US',
#   'sunrise': 1618049451,
#   'sunset': 1618096778},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Looping through ENUMERATE method

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = weather_url + "&q=" + city.replace(" ","+")
    

    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | bonavista
# Processing Record 25 of Set 1 | kautokeino
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | eskasem
# City not found. Skipping...
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | muros
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | carballo
# Processing Record 34 of Set 1 | atikokan
# Processing Record 35 of Set 1 | newport
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | craig
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | nioro
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | duz
# City not found. Skipping...
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | sao joao da barra
# Processing Record 48 of Set 1 | gidole
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | buariki
# City not found. Skipping...
# Processing Record 51 of Set 1 | moanda
# Processing Record 52 of Set 1 | port alfred
# Processing Record 53 of Set 1 | heiligenhafen
# Processing Record 54 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 55 of Set 1 | mercedes
# Processing Record 56 of Set 1 | vaini
# Processing Record 57 of Set 1 | yuma
# Processing Record 58 of Set 1 | punta arenas
# Processing Record 59 of Set 1 | port hardy
# Processing Record 60 of Set 1 | sao filipe
# Processing Record 61 of Set 1 | nome
# Processing Record 62 of Set 1 | busselton
# Processing Record 63 of Set 1 | parras
# City not found. Skipping...
# Processing Record 64 of Set 1 | coos bay
# Processing Record 65 of Set 1 | vao
# Processing Record 66 of Set 1 | nemuro
# Processing Record 67 of Set 1 | lebu
# Processing Record 68 of Set 1 | esperance
# Processing Record 69 of Set 1 | dunedin
# Processing Record 70 of Set 1 | codrington
# Processing Record 71 of Set 1 | saint george
# Processing Record 1 of Set 2 | vestmannaeyjar
# Processing Record 2 of Set 2 | mount isa
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 2 | quebec
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | chuy
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | abeche
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | fairbanks
# Processing Record 13 of Set 2 | marawi
# Processing Record 14 of Set 2 | yumen
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | great yarmouth
# Processing Record 17 of Set 2 | mehamn
# Processing Record 18 of Set 2 | trinidad
# Processing Record 19 of Set 2 | whitianga
# Processing Record 20 of Set 2 | imeni poliny osipenko
# Processing Record 21 of Set 2 | marion
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | atambua
# Processing Record 25 of Set 2 | key west
# Processing Record 26 of Set 2 | avarua
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | bilma
# Processing Record 30 of Set 2 | monte alegre
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | ukiah
# Processing Record 33 of Set 2 | sinkat
# City not found. Skipping...
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | kaitangata
# Processing Record 36 of Set 2 | chernyshevskiy
# Processing Record 37 of Set 2 | isangel
# Processing Record 38 of Set 2 | pontes e lacerda
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | high level
# Processing Record 41 of Set 2 | thompson
# Processing Record 42 of Set 2 | merauke
# Processing Record 43 of Set 2 | fort nelson
# Processing Record 44 of Set 2 | bredasdorp
# Processing Record 45 of Set 2 | okhotsk
# Processing Record 46 of Set 2 | lac du bonnet
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | awjilah
# Processing Record 49 of Set 2 | los llanos de aridane
# Processing Record 50 of Set 2 | san ignacio
# Processing Record 1 of Set 3 | andros
# Processing Record 2 of Set 3 | viedma
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | arlit
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | grand island
# Processing Record 7 of Set 3 | cidreira
# Processing Record 8 of Set 3 | cayenne
# Processing Record 9 of Set 3 | clarksburg
# Processing Record 10 of Set 3 | neiafu
# Processing Record 11 of Set 3 | buraydah
# Processing Record 12 of Set 3 | loviisa
# Processing Record 13 of Set 3 | suntar
# Processing Record 14 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | kutum
# Processing Record 17 of Set 3 | yeppoon
# Processing Record 18 of Set 3 | goderich
# Processing Record 19 of Set 3 | gazanjyk
# Processing Record 20 of Set 3 | bodden town
# Processing Record 21 of Set 3 | jamestown
# Processing Record 22 of Set 3 | upington
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | xining
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | ponta do sol
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | kostino
# Processing Record 30 of Set 3 | biak
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | skjervoy
# Processing Record 33 of Set 3 | jutai
# Processing Record 34 of Set 3 | samarai
# Processing Record 35 of Set 3 | tukrah
# Processing Record 36 of Set 3 | nieuw amsterdam
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | kirillov
# Processing Record 41 of Set 3 | tomatlan
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | korem
# Processing Record 45 of Set 3 | klaksvik
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | alabaster
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | tamandare
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | vostok
# Processing Record 2 of Set 4 | bluff
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | chokurdakh
# Processing Record 6 of Set 4 | kijang
# Processing Record 7 of Set 4 | half moon bay
# Processing Record 8 of Set 4 | ingham
# Processing Record 9 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 10 of Set 4 | manjeshwar
# Processing Record 11 of Set 4 | znamenskoye
# Processing Record 12 of Set 4 | faya
# Processing Record 13 of Set 4 | mackay
# Processing Record 14 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 4 | conceicao da barra
# Processing Record 17 of Set 4 | rio gallegos
# Processing Record 18 of Set 4 | hithadhoo
# Processing Record 19 of Set 4 | inirida
# Processing Record 20 of Set 4 | plettenberg bay
# Processing Record 21 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 22 of Set 4 | uppsala
# Processing Record 23 of Set 4 | storforshei
# Processing Record 24 of Set 4 | leh
# Processing Record 25 of Set 4 | khudumelapye
# Processing Record 26 of Set 4 | henties bay
# Processing Record 27 of Set 4 | aksu
# Processing Record 28 of Set 4 | kudahuvadhoo
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | tinaquillo
# Processing Record 31 of Set 4 | amalapuram
# Processing Record 32 of Set 4 | moranbah
# Processing Record 33 of Set 4 | sola
# Processing Record 34 of Set 4 | tuktoyaktuk
# Processing Record 35 of Set 4 | airai
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | marsh harbour
# Processing Record 38 of Set 4 | jalu
# Processing Record 39 of Set 4 | katobu
# Processing Record 40 of Set 4 | batagay-alyta
# Processing Record 41 of Set 4 | calama
# Processing Record 42 of Set 4 | itarema
# Processing Record 43 of Set 4 | nizhniy kuranakh
# Processing Record 44 of Set 4 | changji
# Processing Record 45 of Set 4 | lompoc
# Processing Record 46 of Set 4 | pavlivka
# Processing Record 47 of Set 4 | sorland
# Processing Record 48 of Set 4 | agadez
# Processing Record 49 of Set 4 | hofn
# Processing Record 50 of Set 4 | nioki
# Processing Record 1 of Set 5 | port elizabeth
# Processing Record 2 of Set 5 | turtkul
# City not found. Skipping...
# Processing Record 3 of Set 5 | yumbe
# Processing Record 4 of Set 5 | ancud
# Processing Record 5 of Set 5 | egvekinot
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | whitehorse
# Processing Record 8 of Set 5 | flin flon
# Processing Record 9 of Set 5 | grand-santi
# Processing Record 10 of Set 5 | bemidji
# Processing Record 11 of Set 5 | sal rei
# Processing Record 12 of Set 5 | oktyabrskiy
# Processing Record 13 of Set 5 | santa lucia
# Processing Record 14 of Set 5 | mirabad
# Processing Record 15 of Set 5 | micheweni
# Processing Record 16 of Set 5 | fortuna
# Processing Record 17 of Set 5 | brae
# Processing Record 18 of Set 5 | luderitz
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | hobart
# Processing Record 21 of Set 5 | sandwick
# Processing Record 22 of Set 5 | emerald
# Processing Record 23 of Set 5 | vardo
# Processing Record 24 of Set 5 | pokhara
# Processing Record 25 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 5 | holme
# Processing Record 27 of Set 5 | chifeng
# Processing Record 28 of Set 5 | lagos
# Processing Record 29 of Set 5 | presidencia roque saenz pena
# Processing Record 30 of Set 5 | vila do maio
# Processing Record 31 of Set 5 | kiboga
# Processing Record 32 of Set 5 | asfi
# Processing Record 33 of Set 5 | druzhba
# Processing Record 34 of Set 5 | manali
# Processing Record 35 of Set 5 | ilhabela
# Processing Record 36 of Set 5 | sinnamary
# Processing Record 37 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 5 | ko samui
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | grafton
# Processing Record 42 of Set 5 | srednekolymsk
# Processing Record 43 of Set 5 | grindavik
# Processing Record 44 of Set 5 | novo aripuana
# Processing Record 45 of Set 5 | necochea
# Processing Record 46 of Set 5 | phalombe
# Processing Record 47 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 5 | faanui
# Processing Record 49 of Set 5 | sioux lookout
# Processing Record 50 of Set 5 | meridian
# Processing Record 1 of Set 6 | scarborough
# Processing Record 2 of Set 6 | mahibadhoo
# Processing Record 3 of Set 6 | port blair
# Processing Record 4 of Set 6 | abalak
# Processing Record 5 of Set 6 | eshowe
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | katangli
# Processing Record 8 of Set 6 | kenora
# Processing Record 9 of Set 6 | mogzon
# Processing Record 10 of Set 6 | acara
# Processing Record 11 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | tupik
# Processing Record 13 of Set 6 | sakakah
# Processing Record 14 of Set 6 | bengkulu
# Processing Record 15 of Set 6 | irondequoit
# Processing Record 16 of Set 6 | pacific grove
# Processing Record 17 of Set 6 | vila franca do campo
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | cape coast
# Processing Record 20 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | samfya
# Processing Record 23 of Set 6 | luau
# Processing Record 24 of Set 6 | vitim
# Processing Record 25 of Set 6 | tautira
# Processing Record 26 of Set 6 | leningradskiy
# Processing Record 27 of Set 6 | aklavik
# Processing Record 28 of Set 6 | monrovia
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | dukat
# Processing Record 31 of Set 6 | coquimbo
# Processing Record 32 of Set 6 | kloulklubed
# Processing Record 33 of Set 6 | sabha
# Processing Record 34 of Set 6 | palma di montechiaro
# Processing Record 35 of Set 6 | misratah
# Processing Record 36 of Set 6 | flinders
# Processing Record 37 of Set 6 | hollola
# Processing Record 38 of Set 6 | kavaratti
# Processing Record 39 of Set 6 | oistins
# Processing Record 40 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 41 of Set 6 | palana
# Processing Record 42 of Set 6 | altamura
# Processing Record 43 of Set 6 | moratuwa
# Processing Record 44 of Set 6 | kindu
# Processing Record 45 of Set 6 | madanapalle
# Processing Record 46 of Set 6 | sanchor
# Processing Record 47 of Set 6 | marovoay
# Processing Record 48 of Set 6 | inhambane
# Processing Record 49 of Set 6 | berlevag
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | ahipara
# Processing Record 2 of Set 7 | kohtla-jarve
# Processing Record 3 of Set 7 | pangoa
# Processing Record 4 of Set 7 | fengrun
# Processing Record 5 of Set 7 | coronado
# Processing Record 6 of Set 7 | la asuncion
# Processing Record 7 of Set 7 | lewistown
# Processing Record 8 of Set 7 | gat
# Processing Record 9 of Set 7 | san javier
# Processing Record 10 of Set 7 | sisimiut
# Processing Record 11 of Set 7 | dir
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | pimenta bueno
# Processing Record 14 of Set 7 | ankazoabo
# Processing Record 15 of Set 7 | machali
# Processing Record 16 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 7 | mahebourg
# Processing Record 18 of Set 7 | bara
# Processing Record 19 of Set 7 | ust-nera
# Processing Record 20 of Set 7 | san-pedro
# Processing Record 21 of Set 7 | ust-kuyga
# Processing Record 22 of Set 7 | rognan
# Processing Record 23 of Set 7 | shimoda
# Processing Record 24 of Set 7 | bukama
# Processing Record 25 of Set 7 | puerto escondido
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | labuhan
# Processing Record 28 of Set 7 | socorro
# Processing Record 29 of Set 7 | lagoa
# Processing Record 30 of Set 7 | san andres
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | kristiinankaupunki
# Processing Record 33 of Set 7 | altamont
# Processing Record 34 of Set 7 | comodoro rivadavia
# Processing Record 35 of Set 7 | victoria
# Processing Record 36 of Set 7 | davila
# Processing Record 37 of Set 7 | pinos
# Processing Record 38 of Set 7 | kyzyl-suu
# Processing Record 39 of Set 7 | rocha
# Processing Record 40 of Set 7 | linjiang
# Processing Record 41 of Set 7 | shunyi
# Processing Record 42 of Set 7 | tallahassee
# Processing Record 43 of Set 7 | nhulunbuy
# Processing Record 44 of Set 7 | show low
# Processing Record 45 of Set 7 | ranot
# Processing Record 46 of Set 7 | totness
# Processing Record 47 of Set 7 | aykhal
# Processing Record 48 of Set 7 | monte azul paulista
# Processing Record 49 of Set 7 | thatta
# Processing Record 50 of Set 7 | hamilton
# Processing Record 1 of Set 8 | forio
# Processing Record 2 of Set 8 | lasa
# Processing Record 3 of Set 8 | lopsmarka
# Processing Record 4 of Set 8 | asau
# Processing Record 5 of Set 8 | ayagoz
# Processing Record 6 of Set 8 | dzilam gonzalez
# Processing Record 7 of Set 8 | gaya
# Processing Record 8 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 8 | richard toll
# City not found. Skipping...
# Processing Record 11 of Set 8 | viksoyri
# City not found. Skipping...
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | williston
# Processing Record 14 of Set 8 | komsomolskiy
# Processing Record 15 of Set 8 | prescott
# Processing Record 16 of Set 8 | diffa
# Processing Record 17 of Set 8 | kaiwaka
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | candido mendes
# Processing Record 20 of Set 8 | saint-pierre
# Processing Record 21 of Set 8 | kemin
# Processing Record 22 of Set 8 | canberra
# Processing Record 23 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 24 of Set 8 | nusaybin
# Processing Record 25 of Set 8 | castro
# Processing Record 26 of Set 8 | zabol
# Processing Record 27 of Set 8 | chachapoyas
# Processing Record 28 of Set 8 | karratha
# Processing Record 29 of Set 8 | amuntai
# Processing Record 30 of Set 8 | grand-lahou
# Processing Record 31 of Set 8 | atar
# Processing Record 32 of Set 8 | broken hill
# Processing Record 33 of Set 8 | sorong
# Processing Record 34 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 8 | jega
# Processing Record 36 of Set 8 | bartica
# Processing Record 37 of Set 8 | tocantins
# Processing Record 38 of Set 8 | naze
# Processing Record 39 of Set 8 | chake chake
# Processing Record 40 of Set 8 | westport
# Processing Record 41 of Set 8 | katima mulilo
# Processing Record 42 of Set 8 | olafsvik
# Processing Record 43 of Set 8 | dudinka
# Processing Record 44 of Set 8 | moree
# Processing Record 45 of Set 8 | del rio
# Processing Record 46 of Set 8 | omboue
# Processing Record 47 of Set 8 | san luis
# Processing Record 48 of Set 8 | kataysk
# Processing Record 49 of Set 8 | belyy yar
# Processing Record 50 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 9 | lata
# Processing Record 2 of Set 9 | geraldton
# Processing Record 3 of Set 9 | talnakh
# Processing Record 4 of Set 9 | san vicente
# Processing Record 5 of Set 9 | tucurui
# Processing Record 6 of Set 9 | burica
# City not found. Skipping...
# Processing Record 7 of Set 9 | san cristobal
# Processing Record 8 of Set 9 | guider
# Processing Record 9 of Set 9 | pineto
# Processing Record 10 of Set 9 | nanortalik
# Processing Record 11 of Set 9 | usinsk
# Processing Record 12 of Set 9 | kaohsiung
# Processing Record 13 of Set 9 | tevaitoa
# Processing Record 14 of Set 9 | yuksekova
# Processing Record 15 of Set 9 | san pedro
# Processing Record 16 of Set 9 | tanout
# Processing Record 17 of Set 9 | ribeira grande
# Processing Record 18 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 9 | kropotkin
# Processing Record 20 of Set 9 | najran
# Processing Record 21 of Set 9 | college
# Processing Record 22 of Set 9 | antalaha
# Processing Record 23 of Set 9 | nyagan
# Processing Record 24 of Set 9 | novopokrovskaya
# Processing Record 25 of Set 9 | breytovo
# Processing Record 26 of Set 9 | bubaque
# Processing Record 27 of Set 9 | yeniseysk
# Processing Record 28 of Set 9 | tarsus
# Processing Record 29 of Set 9 | saint-augustin
# Processing Record 30 of Set 9 | mitu
# Processing Record 31 of Set 9 | bonga
# Processing Record 32 of Set 9 | beringovskiy
# Processing Record 33 of Set 9 | trindade
# Processing Record 34 of Set 9 | sonoita
# Processing Record 35 of Set 9 | hit
# Processing Record 36 of Set 9 | maykain
# City not found. Skipping...
# Processing Record 37 of Set 9 | san vicente de canete
# Processing Record 38 of Set 9 | baboua
# City not found. Skipping...
# Processing Record 39 of Set 9 | kahului
# Processing Record 40 of Set 9 | santa rosa
# Processing Record 41 of Set 9 | torit
# Processing Record 42 of Set 9 | havoysund
# Processing Record 43 of Set 9 | sangar
# Processing Record 44 of Set 9 | antsohihy
# Processing Record 45 of Set 9 | mayo
# Processing Record 46 of Set 9 | poum
# Processing Record 47 of Set 9 | havelock
# Processing Record 48 of Set 9 | mayskiy
# Processing Record 49 of Set 9 | medina
# Processing Record 50 of Set 9 | padang
# Processing Record 1 of Set 10 | zomba
# Processing Record 2 of Set 10 | talas
# Processing Record 3 of Set 10 | shelburne
# Processing Record 4 of Set 10 | nelson bay
# Processing Record 5 of Set 10 | malinovskiy
# Processing Record 6 of Set 10 | bandarbeyla
# Processing Record 7 of Set 10 | skibbereen
# Processing Record 8 of Set 10 | basco
# Processing Record 9 of Set 10 | uk
# City not found. Skipping...
# Processing Record 10 of Set 10 | hsintien
# City not found. Skipping...
# Processing Record 11 of Set 10 | karasjok
# Processing Record 12 of Set 10 | port macquarie
# Processing Record 13 of Set 10 | am timan
# Processing Record 14 of Set 10 | cabo san lucas
# Processing Record 15 of Set 10 | namatanai
# Processing Record 16 of Set 10 | atasu
# Processing Record 17 of Set 10 | villefranche-de-rouergue
# Processing Record 18 of Set 10 | boa vista
# Processing Record 19 of Set 10 | diamantino
# Processing Record 20 of Set 10 | batagay
# Processing Record 21 of Set 10 | pangnirtung
# Processing Record 22 of Set 10 | wanning
# Processing Record 23 of Set 10 | ningxiang
# Processing Record 24 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 10 | hearst
# Processing Record 26 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 10 | caruray
# Processing Record 28 of Set 10 | abha
# Processing Record 29 of Set 10 | matay
# Processing Record 30 of Set 10 | camopi
# Processing Record 31 of Set 10 | allapalli
# Processing Record 32 of Set 10 | shitanjing
# Processing Record 33 of Set 10 | sayyan
# Processing Record 34 of Set 10 | bakchar
# Processing Record 35 of Set 10 | sindou
# Processing Record 36 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 37 of Set 10 | ust-ilimsk
# Processing Record 38 of Set 10 | bembereke
# Processing Record 39 of Set 10 | saldanha
# Processing Record 40 of Set 10 | ville-marie
# Processing Record 41 of Set 10 | daru
# Processing Record 42 of Set 10 | kirakira
# Processing Record 43 of Set 10 | yaan
# Processing Record 44 of Set 10 | maymyo
# Processing Record 45 of Set 10 | vagur
# Processing Record 46 of Set 10 | lingao
# Processing Record 47 of Set 10 | ramanuj ganj
# Processing Record 48 of Set 10 | tandalti
# Processing Record 49 of Set 10 | elizabeth city
# Processing Record 50 of Set 10 | urumqi
# Processing Record 1 of Set 11 | sindor
# Processing Record 2 of Set 11 | honavar
# Processing Record 3 of Set 11 | kachug
# Processing Record 4 of Set 11 | merritt island
# Processing Record 5 of Set 11 | dhidhdhoo
# Processing Record 6 of Set 11 | america dourada
# Processing Record 7 of Set 11 | katherine
# Processing Record 8 of Set 11 | ust-tsilma
# Processing Record 9 of Set 11 | salalah
# Processing Record 10 of Set 11 | opava
# Processing Record 11 of Set 11 | wajir
# Processing Record 12 of Set 11 | juneau
# Processing Record 13 of Set 11 | tikrit
# Processing Record 14 of Set 11 | abu samrah
# Processing Record 15 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 11 | anadyr
# Processing Record 17 of Set 11 | korla
# Processing Record 18 of Set 11 | brownsville
# Processing Record 19 of Set 11 | canton
# Processing Record 20 of Set 11 | terrace
# Processing Record 21 of Set 11 | mugur-aksy
# Processing Record 22 of Set 11 | tamuin
# Processing Record 23 of Set 11 | rockport
# Processing Record 24 of Set 11 | tono
# Processing Record 25 of Set 11 | wukari
# Processing Record 26 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 27 of Set 11 | cassia
# Processing Record 28 of Set 11 | port-cartier
# Processing Record 29 of Set 11 | rock sound
# Processing Record 30 of Set 11 | ballina
# Processing Record 31 of Set 11 | portel
# Processing Record 32 of Set 11 | cabedelo
# Processing Record 33 of Set 11 | iqaluit
# Processing Record 34 of Set 11 | suarez
# Processing Record 35 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 11 | nabire
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | taoudenni
# Processing Record 39 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 11 | kitami
# Processing Record 41 of Set 11 | halkirk
# Processing Record 42 of Set 11 | ostrovnoy
# Processing Record 43 of Set 11 | xinye
# Processing Record 44 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 11 | yamada
# Processing Record 46 of Set 11 | kavieng
# Processing Record 47 of Set 11 | broome
# Processing Record 48 of Set 11 | sungaipenuh
# Processing Record 49 of Set 11 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 50 of Set 11 | ibipeba
# Processing Record 1 of Set 12 | mahenge
# Processing Record 2 of Set 12 | yulara
# Processing Record 3 of Set 12 | kawalu
# Processing Record 4 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 5 of Set 12 | hami
# Processing Record 6 of Set 12 | timizart
# Processing Record 7 of Set 12 | mudanjiang
# Processing Record 8 of Set 12 | waipawa
# Processing Record 9 of Set 12 | sechura
# Processing Record 10 of Set 12 | nichinan
# Processing Record 11 of Set 12 | dalvik
# Processing Record 12 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 12 | carutapera
# Processing Record 14 of Set 12 | alyangula
# Processing Record 15 of Set 12 | tura
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | moyale
# Processing Record 18 of Set 12 | fort oglethorpe
# Processing Record 19 of Set 12 | omsukchan
# Processing Record 20 of Set 12 | hualmay
# Processing Record 21 of Set 12 | guiglo
# Processing Record 22 of Set 12 | iquitos
# Processing Record 23 of Set 12 | ocos
# Processing Record 24 of Set 12 | san bartolome de tirajana
# Processing Record 25 of Set 12 | lishu
# Processing Record 26 of Set 12 | port hueneme
# Processing Record 27 of Set 12 | owando
# Processing Record 28 of Set 12 | pambujan
# Processing Record 29 of Set 12 | pevek
# Processing Record 30 of Set 12 | kungurtug
# Processing Record 31 of Set 12 | paso de carrasco
# Processing Record 32 of Set 12 | bernau
# Processing Record 33 of Set 12 | heinola
# Processing Record 34 of Set 12 | akyab
# Processing Record 35 of Set 12 | altay
# Processing Record 36 of Set 12 | tiruchchendur
# Processing Record 37 of Set 12 | shenjiamen
# Processing Record 38 of Set 12 | mopipi
# Processing Record 39 of Set 12 | rawson
# Processing Record 40 of Set 12 | paamiut
# Processing Record 41 of Set 12 | mugan
# Processing Record 42 of Set 12 | conceicao do araguaia
# Processing Record 43 of Set 12 | santa rosa de viterbo
# Processing Record 44 of Set 12 | vanimo
# Processing Record 45 of Set 12 | ojinaga
# Processing Record 46 of Set 12 | haines junction
# Processing Record 47 of Set 12 | saint-joseph
# Processing Record 48 of Set 12 | tendukheda
# Processing Record 49 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 12 | kalinovskaya
# Processing Record 1 of Set 13 | glendive
# Processing Record 2 of Set 13 | bayevo
# Processing Record 3 of Set 13 | noumea
# Processing Record 4 of Set 13 | porto velho
# Processing Record 5 of Set 13 | callander
# Processing Record 6 of Set 13 | camacha
# Processing Record 7 of Set 13 | gatton
# Processing Record 8 of Set 13 | nizwa
# Processing Record 9 of Set 13 | chapais
# Processing Record 10 of Set 13 | athabasca
# Processing Record 11 of Set 13 | maniitsoq
# Processing Record 12 of Set 13 | quang ngai
# Processing Record 13 of Set 13 | narsaq
# Processing Record 14 of Set 13 | burns lake
# Processing Record 15 of Set 13 | quatre cocos
# Processing Record 16 of Set 13 | riyadh
# Processing Record 17 of Set 13 | jardim
# Processing Record 18 of Set 13 | husavik
# Processing Record 19 of Set 13 | trairi
# Processing Record 20 of Set 13 | kurilsk
# Processing Record 21 of Set 13 | muisne
# Processing Record 22 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 13 | isabela
# Processing Record 24 of Set 13 | thinadhoo
# Processing Record 25 of Set 13 | bull savanna
# Processing Record 26 of Set 13 | cao bang
# Processing Record 27 of Set 13 | vallenar
# Processing Record 28 of Set 13 | ljungby
# Processing Record 29 of Set 13 | yanam
# Processing Record 30 of Set 13 | berbera
# Processing Record 31 of Set 13 | arequipa
# Processing Record 32 of Set 13 | kastamonu
# Processing Record 33 of Set 13 | gurgan
# City not found. Skipping...
# Processing Record 34 of Set 13 | rio grande
# Processing Record 35 of Set 13 | salamiyah
# Processing Record 36 of Set 13 | san jose
# Processing Record 37 of Set 13 | voh
# Processing Record 38 of Set 13 | bambanglipuro
# Processing Record 39 of Set 13 | mao
# Processing Record 40 of Set 13 | la palma
# Processing Record 41 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 13 | tateyama
# Processing Record 43 of Set 13 | natal
# Processing Record 44 of Set 13 | lianzhou
# Processing Record 45 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 46 of Set 13 | yining
# Processing Record 47 of Set 13 | treinta y tres
# Processing Record 48 of Set 13 | buala
# Processing Record 49 of Set 13 | teya
# Processing Record 50 of Set 13 | barranca
# Processing Record 1 of Set 14 | auki
# Processing Record 2 of Set 14 | aliaga
# Processing Record 3 of Set 14 | sao felix do xingu
# Processing Record 4 of Set 14 | nipawin
# Processing Record 5 of Set 14 | adet
# Processing Record 6 of Set 14 | zhangye
# Processing Record 7 of Set 14 | gawler
# Processing Record 8 of Set 14 | varhaug
# Processing Record 9 of Set 14 | santa marta
# Processing Record 10 of Set 14 | faratsiho
# Processing Record 11 of Set 14 | te anau
# Processing Record 12 of Set 14 | slave lake
# Processing Record 13 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 14 | esso
# Processing Record 15 of Set 14 | watsa
# Processing Record 16 of Set 14 | onega
# Processing Record 17 of Set 14 | vilhena
# Processing Record 18 of Set 14 | maiduguri
# Processing Record 19 of Set 14 | denpasar
# Processing Record 20 of Set 14 | eregli
# Processing Record 21 of Set 14 | tonj
# Processing Record 22 of Set 14 | qasigiannguit
# Processing Record 23 of Set 14 | arroio grande
# Processing Record 24 of Set 14 | polson
# Processing Record 25 of Set 14 | alice springs
# Processing Record 26 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 14 | veraval
# Processing Record 28 of Set 14 | ekibastuz
# Processing Record 29 of Set 14 | lake havasu city
# Processing Record 30 of Set 14 | waterloo
# Processing Record 31 of Set 14 | ruwi
# Processing Record 32 of Set 14 | coello
# Processing Record 33 of Set 14 | forbes
# Processing Record 34 of Set 14 | xai-xai
# Processing Record 35 of Set 14 | celestun
# Processing Record 36 of Set 14 | malinyi
# Processing Record 37 of Set 14 | rostovka
# Processing Record 38 of Set 14 | pemangkat
# Processing Record 39 of Set 14 | xinyu
# Processing Record 40 of Set 14 | tual
# Processing Record 41 of Set 14 | luganville
# Processing Record 42 of Set 14 | uberlandia
# Processing Record 43 of Set 14 | azare
# Processing Record 44 of Set 14 | marzuq
# Processing Record 45 of Set 14 | cap malheureux
# Processing Record 46 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 47 of Set 14 | smithers
# Processing Record 48 of Set 14 | zhigansk
# Processing Record 49 of Set 14 | zhob
# Processing Record 50 of Set 14 | christchurch
# Processing Record 1 of Set 15 | san carlos del zulia
# Processing Record 2 of Set 15 | novobirilyussy
# Processing Record 3 of Set 15 | middle island
# Processing Record 4 of Set 15 | waddan
# Processing Record 5 of Set 15 | nyurba
# Processing Record 6 of Set 15 | tinskoy
# Processing Record 7 of Set 15 | alvarado
# Processing Record 8 of Set 15 | newcastle
# Processing Record 9 of Set 15 | swedru
# Processing Record 10 of Set 15 | maceio
# Processing Record 11 of Set 15 | alamosa
# Processing Record 12 of Set 15 | tazmalt
# Processing Record 13 of Set 15 | de panne
# Processing Record 14 of Set 15 | popondetta
# Processing Record 15 of Set 15 | severnyy
# Processing Record 16 of Set 15 | mantua
# Processing Record 17 of Set 15 | saint-francois
# Processing Record 18 of Set 15 | uncia
# Processing Record 19 of Set 15 | oum hadjer
# Processing Record 20 of Set 15 | jalesar
# Processing Record 21 of Set 15 | senmonorom
# City not found. Skipping...
# Processing Record 22 of Set 15 | ketchikan
# Processing Record 23 of Set 15 | erdenet
# Processing Record 24 of Set 15 | gravdal
# Processing Record 25 of Set 15 | kibala
# Processing Record 26 of Set 15 | tuy hoa
# Processing Record 27 of Set 15 | dong hoi
# Processing Record 28 of Set 15 | valls
# Processing Record 29 of Set 15 | maturin
# Processing Record 30 of Set 15 | coahuayana
# Processing Record 31 of Set 15 | lososina
# Processing Record 32 of Set 15 | jiblah
# Processing Record 33 of Set 15 | evensk
# Processing Record 34 of Set 15 | ocampo
# Processing Record 35 of Set 15 | rongcheng
# Processing Record 36 of Set 15 | washougal
# Processing Record 37 of Set 15 | new plymouth
# Processing Record 38 of Set 15 | muzhi
# Processing Record 39 of Set 15 | mahaena
# City not found. Skipping...
# Processing Record 40 of Set 15 | gornopravdinsk
# Processing Record 41 of Set 15 | sao paulo de olivenca
# Processing Record 42 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 15 | bela
# Processing Record 44 of Set 15 | freeport
# Processing Record 45 of Set 15 | miragoane
# Processing Record 46 of Set 15 | sur
# Processing Record 47 of Set 15 | gizo
# Processing Record 48 of Set 15 | zeya
# Processing Record 49 of Set 15 | villa carlos paz
# Processing Record 50 of Set 15 | narasannapeta
# Processing Record 1 of Set 16 | laurel
# Processing Record 2 of Set 16 | maragogi
# Processing Record 3 of Set 16 | sao gabriel da cachoeira
# Processing Record 4 of Set 16 | jupiter
# Processing Record 5 of Set 16 | puksoozero
# Processing Record 6 of Set 16 | contamana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# []

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
#print(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Carnarvon -24.8667  113.6333     77.00        88          97
# 1          Sitka  57.0531 -135.3300     33.80        75          90
# 2      Bonavista  48.6499  -53.1147     32.00       100         100
# 3     Kautokeino  69.0125   23.0412      7.79        77           6
# 4  Mount Gambier -37.8333  140.7667     50.00        66          40
# 5      Tuatapere -46.1333  167.6833     57.00        94          80
# 6          Kapaa  22.0752 -159.3190     70.00        83          90
# 7          Muros  42.7762   -9.0603     57.99        82          99
# 8         Bethel  41.3712  -73.4140     69.80        56          75
# 9       Carballo  43.2130   -8.6910     54.00        93          98
#
#    Wind Speed      Description
# 0       13.80  overcast clouds
# 1       11.50             snow
# 2        5.75  overcast clouds
# 3        8.46        clear sky
# 4       19.57       light rain
# 5        3.00    broken clouds
# 6        6.91  overcast clouds
# 7        6.20  overcast clouds
# 8        9.22    broken clouds
# 9       11.99  overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
